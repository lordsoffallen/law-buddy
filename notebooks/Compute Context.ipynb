# %%
! git clone https://github.com/lordsoffallen/law-buddy.git && \
cd ./law-buddy/ && \
git checkout v2 && \
pip install -q datasets unstructured kedro kedro_datasets faiss-cpu==1.7.2 && \
cp -r /content/law-buddy/data/ /content/data/
# Out:
# Cloning into 'law-buddy'...
# remote: Enumerating objects: 164, done.
# remote: Counting objects: 100% (164/164), done.
# remote: Compressing objects: 100% (108/108), done.
# remote: Total 164 (delta 76), reused 140 (delta 52), pack-reused 0
# Receiving objects: 100% (164/164), 70.88 KiB | 2.15 MiB/s, done.
# Resolving deltas: 100% (76/76), done.
# Branch 'v2' set up to track remote branch 'v2' from 'origin'.
# Switched to a new branch 'v2'
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.6/536.6 kB 3.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 15.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.9/162.9 kB 20.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 144.8/144.8 kB 17.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 29.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.3/38.3 MB 12.8 MB/s eta 0:00:00
# ...

# %%
import sys

# Add cloned directory to sys path to be able to load libs/packages
sys.path.extend([
    '/content/law-buddy',
    '/content/law-buddy/',
    '/content/law-buddy/src',
    '/content/law-buddy/src/'
    ])

# %%
from kedro.framework.session import KedroSession
from kedro.framework.startup import bootstrap_project
from pathlib import Path

# Setup kedro
PROJECT_PATH = Path.joinpath(Path.cwd(), 'law-buddy')
metadata = bootstrap_project(PROJECT_PATH)
metadata
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ProjectMetadata(
#     config_file=PosixPath('/content/law-buddy/pyproject.toml'),
#     package_name='law_buddy',
#     project_name='law-buddy',
#     project_path=PosixPath('/content/law-buddy'),
#     source_dir=PosixPath('/content/law-buddy/src'),
#     kedro_init_version='0.19.2',
#     tools=['Linting', 'Testing', 'Custom Logging', 'Data Structure'],
#     example_pipeline='False'
# )

# %%
with KedroSession.create(PROJECT_PATH) as session:
    session.run(node_names=['get_question_context'])      # Define which nodes to run
# Out:
# [02/13/24 17:56:11] INFO     Kedro project law-buddy                                                 ]8;id=375380;file:///usr/local/lib/python3.10/dist-packages/kedro/framework/session/session.py\session.py]8;;\:]8;id=664723;file:///usr/local/lib/python3.10/dist-packages/kedro/framework/session/session.py#321\321]8;;\
#                     INFO     Using synchronous mode for loading and saving data. Use the    ]8;id=325675;file:///usr/local/lib/python3.10/dist-packages/kedro/runner/sequential_runner.py\sequential_runner.py]8;;\:]8;id=441704;file:///usr/local/lib/python3.10/dist-packages/kedro/runner/sequential_runner.py#64\64]8;;\
#                              --async flag for potential performance gains.
#                              https://docs.kedro.org/en/stable/nodes_and_pipelines/run_a_pip
#                              eline.html#load-and-save-asynchronously
# ...
